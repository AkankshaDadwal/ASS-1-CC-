# %%
print("hello")
print("hello")
print("hello")
print("hello")

a =10
b =20
c= a+b
print(a,"+", b,"--->",c)

a= "ramesh"
b= "suresh"
c="ram"
d=a+b+c
print(a,"+", b,"+", c,"---->",d)

for i in range (1,11):
 print(7,"*",i,"=",i*7)

for i in range (1,11):
 print(9, "*",i,"=",i*9)

a = int(input("first number"))

b = int(input("first number"))
if a == b:
	print ("a == b")
elif a >= b:
	print ("a > b")
else:
	print ("a < b")


def sum_of_odds(n):
  return sum(number for number in range(1, n + 1) if number % 2 != 0)

n = input("Enter a positive integer: ")
if n.isdigit() and int(n) > 0:
  n = int(n)
  print(f"The sum of all odd numbers from 1 to {n} is: {sum_of_odds(n)}")
else:
  print("Invalid input! Please enter a positive integer.")

def is_prime(num):
  if num < 2:
      return False
  for i in range(2, int(num**0.5) + 1):
      if num % i == 0:
          return False
  return True

def sum_of_primes(n):
  return sum(number for number in range(2, n + 1) if is_prime(number))

n = input("Enter a positive integer: ")
if n.isdigit() and int(n) > 0:
    n = int(n)
    print(f"The sum of all prime numbers from 1 to {n} is: {sum_of_primes(n)}")
else:
    print("Invalid input! Please enter a positive integer.")



def sum_of_numbers_divisible_by_7_and_9(n):
    total_sum = 0
    for i in range(1, n+1):
        if i % 7 == 0 and i % 9 == 0:
            total_sum += i
    return total_sum

# Input from the user
n = int(input("Enter the value of n: "))

# Calculate and print the sum
result = sum_of_numbers_divisible_by_7_and_9(n)
print(f"The sum of all numbers divisible by 7 and 9 from 1 to {n} is: {result}")


def is_prime(num):
    if num <= 1:
        return False
    for i in range(2, num):
        if num % i == 0:
            return False
    return True

# Function to calculate sum of all prime numbers from 1 to n
def sum_of_primes(n):
    total_sum = 0
    for i in range(1, n+1):
        if is_prime(i):
            total_sum += i
    return total_sum

# Input from the user
n = int(input("Enter the value of n: "))

# Calculate and print the sum
result = sum_of_primes(n)
print(f"The sum of all prime numbers from 1 to {n} is: {result}")



a=int(input("Enter first number"))
b=int(input("Enter second number"))
c=int(input("Enter third number"))
if a>b and a>c:
    print("A is the largest number")
elif b>a and b>c:
    print("B is the largest number")
else:
    print("c is the largest number")
# Out:
# hello
# hello
# hello
# hello
# 10 + 20 ---> 30
# ramesh + suresh + ram ----> rameshsureshram
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 7 * 10 = 70
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81
# 9 * 10 = 90
# first number2
# first number3
# a < b
# Enter a positive integer: 5
# The sum of all odd numbers from 1 to 5 is: 9
# Enter a positive integer: 6
# The sum of all prime numbers from 1 to 6 is: 10
# Enter the value of n: 7
# The sum of all numbers divisible by 7 and 9 from 1 to 7 is: 0
# Enter the value of n: 8
# The sum of all prime numbers from 1 to 8 is: 17
# Enter first number9
# Enter second number7
# Enter third number8
# A is the largest number
